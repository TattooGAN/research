# %%
import os


import instaloader
import yadisk

from decouple import config
from tqdm.notebook import tqdm
from tqdm import trange

# %%
API_KEY = config('KEY')
y = yadisk.YaDisk(token=API_KEY)

assert y.check_token()

# %%
y.download('app:/inkby/000075404a2994f4d7a28fd7bf0f2697_1.jpg', './test.jpg')

# %%
for filename in y.listdir('app:/inkby'):
    print(filename)
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/venv/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0b752497b42f> in <module>
# ----> 1 for filename in y.listdir('app:/inkby'):
#       2     print(filename)
#       3     break
#
# ...
